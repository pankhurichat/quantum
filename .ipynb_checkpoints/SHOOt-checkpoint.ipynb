# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def f(x,v,t):
  r= v
  return r

def g(x,v,t):
  r= -9.8
  return r

def rk4(x0,v0,t0,tn,n):

    h= (tn-t0)/n       # step size h
    time=[t0]          # list of t, x and y to append data
    position=[x0]
    velocity=[v0]
    for i in range(1,n):
      k1 = h*f(x0, v0, t0)
      l1 = h*g(x0, v0, t0)
      k2=h*f(x0+(k1)/2,v0+(l1)/2,t0+(h)/2)
      l2=h*g(x0+(k1)/2,v0+(l1)/2,t0+(h)/2)
      k3=h*f(x0+(k2)/2,v0+(l2)/2,(h)/2)
      l3=h*g(x0+(k2)/2,v0+(l2)/2,(h)/2)
      k4=h*f(x0+k3,v0+l3,t0+h)
      l4=h*g(x0+k3,v0+l3,t0+h)
        
        
      x1 = x0 + (1/6)*(k1+2*k2+2*k3+k4)
      v1 = v0 + (1/6)*(l1+2*l2+2*l3+l4)
      t1 = t0 + h
      position.append(x1)
      velocity.append(v1)
      time.append(t1)

      x0 = x1         # assign the modified values og x0 and y0 for the next iteration
      v0 = v1
      t0 = t1

    return (position,velocity,time)

# %%
x0=0
v0=10
t0=0
tn=10
n=1000
v1=50
x,v,t=rk4(x0,v0,t0,tn,n)
x1,v1,t1=rk4(x0,v1,t0,tn,n)

plt.plot(t,x)
plt.plot(t1,x1)

# %%
def bisection(a,b,f,e):
    if f(a)*f(b)>0:
        print("enter other interval")
    while (abs(b-a)>e):
        c=(a+b)/2
        if f(a)*f(c)<0:
            b=c
        if f(b)*f(c)<0:
            a=c
    return c

# %%
def z(v):
    p,q,r=rk4(x0,v,t0,tn,n)
    return p[-1]

# %%
v3=bisection(v0,v1,z,.01)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 v3=bisection(v0,v1,z,.01)
#
# Input In [11], in bisection(a, b, f, e)
#       1 def bisection(a,b,f,e):
# ----> 2     if f(a)*f(b)>0:
#       3         print("enter other interval")
#       4     while (abs(b-a)>e):
#
# Input In [12], in z(v)
#       1 def z(v):
# ----> 2     p,q,r=rk4(x0,v,t0,tn,n)
#       3     return p[-1]
#
# Input In [9], in rk4(x0, v0, t0, tn, n)
#      14 velocity=[v0]
#      15 for i in range(1,n):
# ---> 16   k1 = h*f(x0, v0, t0)
#      17   l1 = h*g(x0, v0, t0)
#      18   k2=h*f(x0+(k1)/2,v0+(l1)/2,t0+(h)/2)
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
def V(x):
    return 0
def function(x,E):
    m=9.1*10e-31
    h_cross=1.0546*10e-27
    return (V(x)-E)

# %%
def y(x,E,h):
    return 1-(h**2*function(x,E))/12

# %%
def numerov(x0,xf,E,n):
    psi=np.zeros(n)
    psi[0]=0
    psi[1]=psi[0]+h
    x=np.arange(x0,xf,h)
    for i in range(1,n-1):
        psi[i+1]=(psi[i]*(12-10*y(x[i],E,h))-y(x[i-1],E,h)*psi[i-1])/y(x[i+1],E,h)
    return psi

# %%
x0=-6
xf=6
n=1000
h=(xf-x0)/n
x=np.arange(x0,xf,h)
E1=.05
E2=.09
p1=numerov(x0,xf,E1,n)
plt.plot(x,p1)
p2=numerov(x0,xf,E2,n)
plt.plot(x,p2)

# %%
def q(E):
    return numerov(x0,xf,E,n)[-1]

# %%
en=bisection(E1,E2,q,.01)

# %%
en
# Out:
# 0.065

# %%
En=numerov(x0,xf,en,n)
En[1]
# Out:
# 0.012

# %%
plt.plot(x,En)

# %%
node=0
for i in range(0,len(En)-1):
    if En[i]*En[i+1]<0:
        node+=1

# %%
node
# Out:
# 0

# %%
for i in range(1,5):
    EE=numerov(x0,xf,i,n)
    plt.plot(x,EE)
